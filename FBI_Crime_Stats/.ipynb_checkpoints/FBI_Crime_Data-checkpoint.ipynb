# %% [markdown]
# ## Before starting:
# ### Delete first three rows and all rows under year 2016
#
# ### If there are 'NaNs' in rows and columns under row 21, either select all NaN data, right-click to clear contents, and/or delete the rows
#
# ### Convert all data in CSV to text.  If this isn't performed, when datatypes are looked up, some of the data will be objects.  Converting everything to text will make all data either 'int64' or 'float64'

# %%
# Add Matplotlib inline magic command
# %matplotlib inline

# Import dependecies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statistics

# %%
# File to load 
file_to_load = "Resources/2016_FBI_Crime.csv"

# %%
# Read the crime data
crime_df = pd.read_csv(file_to_load)
crime_df.head()
# Out:
#    Year  Population  Violent_Crime2  Violent_Crime_Rate  \
# 0  1997   267783607         1636096               611.0
# 1  1998   270248003         1533887               567.6
# 2  1999   272690813         1426044               523.0
# 3  2000   281421906         1425486               506.5
# 4  2001   285317559         1439480               504.5
#
#    Murder_and_Nonnegligent_Manslaughter  \
# 0                                 18208
# 1                                 16974
# 2                                 15522
# 3                                 15586
# 4                                 16037
#
#    Murder_and_Nonnegligent_Manslaughter_Rate Rape_Revised_Definition  \
# 0                                        6.8                     NaN
# 1                                        6.3                     NaN
# 2                                        5.7                     NaN
# 3                                        5.5                     NaN
# 4                                        5.6                     NaN
#
#    Rape_Revised_Definition.1  Rape_Legacy_Definition  \
# 0                        NaN                   96153
# 1                        NaN                   93144
# 2                        NaN                   89411
# 3                        NaN                   90178
# 4                        NaN                   90863
#
#    Rape_Legacy_Definition.1  ...  Aggrevated_Assault  Aggrevated_Assault_Rate  \
# 0                      35.9  ...             1023201                    382.1
# 1                      34.5  ...              976583                    361.4
# 2                      32.8  ...              911740                    334.3
# 3                      32.0  ...              911706                    324.0
# 4                      31.8  ...              909023                    318.6
#
#    Property_Crime  Property_Crime_Rate  Burglary  Burglary_Rate  \
# 0        11558475               4316.3   2460526          918.8
# 1        10951827               4052.5   2332735          863.2
# 2        10208334               3743.6   2100739          770.4
# 3        10182584               3618.3   2050992          728.8
# 4        10437189               3658.1   2116531          741.8
#
#    Larcenty_Theft  Larceny_Theft_Rate  Motor_Vehicle_Theft  \
# 0         7743760              2891.8              1354189
# 1         7376311              2729.5              1242781
# 2         6955520              2550.7              1152075
# 3         6971590              2477.3              1160002
# 4         7092267              2485.7              1228391
#
#    Motor_Vehicle_Theft_Rate
# 0                     505.7
# 1                     459.9
# 2                     422.5
# 3                     412.2
# 4                     430.5
#
# [5 rows x 22 columns]

# %%
# Get datatypes for each column
crime_df.dtypes
# Out:
# Year                                           int64
# Population                                     int64
# Violent_Crime2                                 int64
# Violent_Crime_Rate                           float64
# Murder_and_Nonnegligent_Manslaughter           int64
# Murder_and_Nonnegligent_Manslaughter_Rate    float64
# Rape_Revised_Definition                       object
# Rape_Revised_Definition.1                    float64
# Rape_Legacy_Definition                         int64
# Rape_Legacy_Definition.1                     float64
# Robbery                                        int64
# Robbery_Rate                                 float64
# Aggrevated_Assault                             int64
# Aggrevated_Assault_Rate                      float64
# Property_Crime                                 int64
# Property_Crime_Rate                          float64
# Burglary                                       int64
# Burglary_Rate                                float64
# Larcenty_Theft                                 int64
# Larceny_Theft_Rate                           float64
# Motor_Vehicle_Theft                            int64
# Motor_Vehicle_Theft_Rate                     float64
# dtype: object

# %%
# Convert object datatype to int64
#crime_df['Population1'] = crime_df['Population1'].astype(int)

#crime_df['Population1'] = pd.to_numeric(crime_df['Population1'])

#crime_df.dtypes

#df['DataFrame Column'] = pd.to_numeric(df['DataFrame Column'])

# %%
# Get datatypes for each column
crime_df.dtypes
# Out:
# Year                                           int64
# Population                                     int64
# Violent_Crime2                                 int64
# Violent_Crime_Rate                           float64
# Murder_and_Nonnegligent_Manslaughter           int64
# Murder_and_Nonnegligent_Manslaughter_Rate    float64
# Rape_Revised_Definition                       object
# Rape_Revised_Definition.1                    float64
# Rape_Legacy_Definition                         int64
# Rape_Legacy_Definition.1                     float64
# Robbery                                        int64
# Robbery_Rate                                 float64
# Aggrevated_Assault                             int64
# Aggrevated_Assault_Rate                      float64
# Property_Crime                                 int64
# Property_Crime_Rate                          float64
# Burglary                                       int64
# Burglary_Rate                                float64
# Larcenty_Theft                                 int64
# Larceny_Theft_Rate                           float64
# Motor_Vehicle_Theft                            int64
# Motor_Vehicle_Theft_Rate                     float64
# dtype: object

# %%
# Create new dataframe with Year and Population
#new = pd.DataFrame([old.A, old.B, old.C]).transpose()
pop_year_df = pd.DataFrame([crime_df.Year, crime_df.Population]).transpose()
pop_year_df
# Out:
#     Year  Population
# 0   1997   267783607
# 1   1998   270248003
# 2   1999   272690813
# 3   2000   281421906
# 4   2001   285317559
# 5   2002   287973924
# 6   2003   290788976
# 7   2004   293656842
# 8   2005   296507061
# 9   2006   299398484
# 10  2007   301621157
# 11  2008   304059724
# 12  2009   307006550
# 13  2010   309330219
# 14  2011   311587816
# 15  2012   313873685
# 16  2013   316497531
# 17  2014   318907401
# 18  2015   320896618
# 19  2016   323127513

# %%
# Set year as the index
# This is needed to have the year labels display across the x-axis
# If this isn't done, then the current index, 0-19, will display across the x-axis
pop_year_df.set_index('Year', inplace=True)

# %%
# Create a bar chart 
x_labels=["Year"]
ax = pop_year_df.plot(kind='line', title='U.S. Population by Year', figsize=(15,10), 
                      legend=False, fontsize=12)

# Create labels for x- and y-axes
ax.set_xlabel('Year', fontsize=12)
ax.set_ylabel('Population', fontsize=12)

# Set the y limit between 0 and 45
ax.set_ylim(0, 350000000)
# Out:
# (0.0, 350000000.0)

# %%
# Create a bar chart 
x_labels=["Year"]
ax = pop_year_df.plot(kind='bar', title='U.S. Population by Year', figsize=(15,10), 
                      legend=False, fontsize=12)

# Create labels for x- and y-axes
ax.set_xlabel('Year', fontsize=12)
ax.set_ylabel('Population', fontsize=12)

# Set the y limit between 0 and 45
ax.set_ylim(0, 350000000)
# Out:
# (0.0, 350000000.0)
