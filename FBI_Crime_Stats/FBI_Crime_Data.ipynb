# %%
# Add Matplotlib inline magic command
# %matplotlib inline

# Import dependecies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# File to load 
file_to_load = "Resources/2016_FBI_Crime.csv"

# %%
# Read the crime data
crime_df = pd.read_csv(file_to_load)
crime_df.head()
# Out:
#    Year  Population1 Violent\ncrime2  Violent \ncrime \nrate   \
# 0  1997  267,783,607       1,636,096                    611.0
# 1  1998  270,248,003       1,533,887                    567.6
# 2  1999  272,690,813       1,426,044                    523.0
# 3  2000  281,421,906       1,425,486                    506.5
# 4  2001  285,317,559       1,439,480                    504.5
#
#   Murder and\nnonnegligent \nmanslaughter  \
# 0                                  18,208
# 1                                  16,974
# 2                                  15,522
# 3                                  15,586
# 4                                  16,037
#
#    Murder and \nnonnegligent \nmanslaughter \nrate   \
# 0                                               6.8
# 1                                               6.3
# 2                                               5.7
# 3                                               5.5
# 4                                               5.6
#
#   Rape\n(revised \ndefinition3)  Rape\n(revised \ndefinition) \nrate3  \
# 0                           NaN                                   NaN
# 1                           NaN                                   NaN
# 2                           NaN                                   NaN
# 3                           NaN                                   NaN
# 4                           NaN                                   NaN
#
#   Rape\n(legacy \ndefinition4)  Rape\n(legacy \ndefinition) \nrate4  ...  \
# 0                       96,153                                 35.9  ...
# 1                       93,144                                 34.5  ...
# 2                       89,411                                 32.8  ...
# 3                       90,178                                 32.0  ...
# 4                       90,863                                 31.8  ...
#
#   Aggravated \nassault  Aggravated \nassault rate  Property \ncrime  \
# 0            1,023,201                       382.1       11,558,475
# 1              976,583                       361.4       10,951,827
# 2              911,740                       334.3       10,208,334
# 3              911,706                       324.0       10,182,584
# 4              909,023                       318.6       10,437,189
#
#    Property \ncrime \nrate    Burglary Burglary \nrate  Larceny-\ntheft  \
# 0                  4,316.30  2,460,526            918.8       7,743,760
# 1                  4,052.50  2,332,735            863.2       7,376,311
# 2                  3,743.60  2,100,739            770.4       6,955,520
# 3                  3,618.30  2,050,992            728.8       6,971,590
# 4                  3,658.10  2,116,531            741.8       7,092,267
#
#    Larceny-\ntheft rate  Motor \nvehicle \ntheft  \
# 0               2,891.80               1,354,189
# 1               2,729.50               1,242,781
# 2               2,550.70               1,152,075
# 3               2,477.30               1,160,002
# 4               2,485.70               1,228,391
#
#   Motor \nvehicle \ntheft \nrate
# 0                           505.7
# 1                           459.9
# 2                           422.5
# 3                           412.2
# 4                           430.5
#
# [5 rows x 22 columns]

# %%
# Get datatypes for each column
crime_df.dtypes
# Out:
# Year                                                  int64
# Population1                                          object
# Violent\ncrime2                                      object
# Violent \ncrime \nrate                              float64
# Murder and\nnonnegligent \nmanslaughter              object
# Murder and \nnonnegligent \nmanslaughter \nrate     float64
# Rape\n(revised \ndefinition3)                        object
# Rape\n(revised \ndefinition) \nrate3                float64
# Rape\n(legacy \ndefinition4)                         object
# Rape\n(legacy \ndefinition) \nrate4                 float64
# Robbery                                              object
# Robbery \nrate                                      float64
# Aggravated \nassault                                 object
# Aggravated \nassault rate                           float64
# Property \ncrime                                     object
# Property \ncrime \nrate                              object
# Burglary                                             object
# Burglary \nrate                                     float64
# Larceny-\ntheft                                      object
# Larceny-\ntheft rate                                 object
# Motor \nvehicle \ntheft                              object
# Motor \nvehicle \ntheft \nrate                      float64
# dtype: object

# %%
# Convert object datatype to int64
#crime_df['Population1'] = crime_df['Population1'].astype(int)

#crime_df['Population1'] = pd.to_numeric(crime_df['Population1'])

#crime_df.dtypes

#df['DataFrame Column'] = pd.to_numeric(df['DataFrame Column'])

# %%
# Get datatypes for each column
crime_df.dtypes
# Out:
# Year                                                  int64
# Population1                                          object
# Violent\ncrime2                                      object
# Violent \ncrime \nrate                              float64
# Murder and\nnonnegligent \nmanslaughter              object
# Murder and \nnonnegligent \nmanslaughter \nrate     float64
# Rape\n(revised \ndefinition3)                        object
# Rape\n(revised \ndefinition) \nrate3                float64
# Rape\n(legacy \ndefinition4)                         object
# Rape\n(legacy \ndefinition) \nrate4                 float64
# Robbery                                              object
# Robbery \nrate                                      float64
# Aggravated \nassault                                 object
# Aggravated \nassault rate                           float64
# Property \ncrime                                     object
# Property \ncrime \nrate                              object
# Burglary                                             object
# Burglary \nrate                                     float64
# Larceny-\ntheft                                      object
# Larceny-\ntheft rate                                 object
# Motor \nvehicle \ntheft                              object
# Motor \nvehicle \ntheft \nrate                      float64
# dtype: object

# %%
# Create new dataframe with Year and Population1
#new = pd.DataFrame([old.A, old.B, old.C]).transpose()
pop_year_df = pd.DataFrame([crime_df.Year, crime_df.Population1]).transpose()
pop_year_df
# Out:
#     Year  Population1
# 0   1997  267,783,607
# 1   1998  270,248,003
# 2   1999  272,690,813
# 3   2000  281,421,906
# 4   2001  285,317,559
# 5   2002  287,973,924
# 6   2003  290,788,976
# 7   2004  293,656,842
# 8   2005  296,507,061
# 9   2006  299,398,484
# 10  2007  301,621,157
# 11  2008  304,059,724
# 12  2009  307,006,550
# 13  2010  309,330,219
# 14  2011  311,587,816
# 15  2012  313,873,685
# 16  2013  316,497,531
# 17  2014  318,907,401
# 18  2015  320,896,618
# 19  2016  323,127,513

# %%
# Create a bar chart using the MATLAB approach
ax = pop_year_df.plot(kind='bar', title='U.S. Population by Year', figsize=(15,10), legend=True, fontsize=12)
ax.set_xlabel('Year', fontsize=12)
ax.set_ylabel('Population', fontsize=12)
# Out:
# Text(0, 0.5, 'Population')
